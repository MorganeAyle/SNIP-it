# %%
import os
os.chdir("/nfs/homedirs/ayle/guided-research/SNIP-it/learning-invariances")

# %%
from experiments.cifar10.train_augerino import main
from dataclasses import dataclass

# %%
@dataclass
class args:
    epochs = 200
    lr = 0.002
    wd = 5e-5
    transform = "fixed"
    dir = "/nfs/students/ayle/guided-research/gitignored/results/invariances/"
    data_dir = "/nfs/students/ayle/guided-research/gitignored/data"
    ncopies = 4
    batch_size = 512
    aug_reg = 0.001
    custom_name = "new_hyperparam_b512"

# %%
arguments = args()
main(arguments)
# Out:
# Using Cuda
# Epoch =  0
# Epoch loss =  1.936781221506547
# Epoch accuracy =  tensor(0.3559, device='cuda:0')
#
#
# Epoch =  1
# Epoch loss =  1.58761628428284
# Epoch accuracy =  tensor(0.4478, device='cuda:0')
#
#
# Epoch =  2
# Epoch loss =  1.3442501705520007
# Epoch accuracy =  tensor(0.5345, device='cuda:0')
#
#
# Epoch =  3
# Epoch loss =  1.166660997332359
# Epoch accuracy =  tensor(0.6059, device='cuda:0')
#
#
# Epoch =  4
# Epoch loss =  1.0156459558983237
# Epoch accuracy =  tensor(0.6406, device='cuda:0')
#
#
# Epoch =  5
# Epoch loss =  0.9038457000742153
# Epoch accuracy =  tensor(0.6739, device='cuda:0')
#
#
# Epoch =  6
# Epoch loss =  0.8052329092609639
# Epoch accuracy =  tensor(0.7127, device='cuda:0')
#
#
# Epoch =  7
# Epoch loss =  0.719931958281264
# Epoch accuracy =  tensor(0.7488, device='cuda:0')
#
#
# Epoch =  8
# Epoch loss =  0.6467004533933134
# Epoch accuracy =  tensor(0.7696, device='cuda:0')
#
#
# Epoch =  9
# Epoch loss =  0.5802691937709341
# ...

# %%
# !python ./experiments/cifar10/train_augerino.py --epochs=200 \
#                  --lr=0.01 \
#                  --wd=1e-4 \
#                  --transform="none" \
#                  --dir="/nfs/students/ayle/guided-research/gitignored/results/invariances/" \
#                  --data_dir="/nfs/students/ayle/guided-research/gitignored/data" \
#                  --ncopies=4 \
#                  --batch_size=128
