# %%
import os
os.chdir("/nfs/homedirs/ayle/guided-research/SNIP-it/learning-invariances")

# %%
from experiments.cifar10.train_augerino import main
from dataclasses import dataclass

# %%
@dataclass
class args:
    epochs = 80
    lr = 0.002
    wd = 5e-5
    transform = "none"
    dir = "/nfs/students/ayle/guided-research/gitignored/results/invariances/"
    data_dir = "/nfs/students/ayle/guided-research/gitignored/data"
    ncopies = 4
    batch_size = 512
    aug_reg = 0.001
    custom_name = "new_hyperparam_b512"

# %%
arguments = args()
main(arguments)
# Out:
# Using Cuda
# Epoch =  0
# Epoch loss =  1.8902045220744854
# Epoch accuracy =  tensor(0.3883, device='cuda:0')
#
#
# Epoch =  1
# Epoch loss =  1.494507568223136
# Epoch accuracy =  tensor(0.5015, device='cuda:0')
#
#
# Epoch =  2
# Epoch loss =  1.247561835512823
# Epoch accuracy =  tensor(0.5863, device='cuda:0')
#
#
# Epoch =  3
# Epoch loss =  1.0469584087936246
# Epoch accuracy =  tensor(0.6484, device='cuda:0')
#
#
# Epoch =  4
# Epoch loss =  0.8976749491934873
# Epoch accuracy =  tensor(0.6990, device='cuda:0')
#
#
# Epoch =  5
# Epoch loss =  0.7817748985728439
# Epoch accuracy =  tensor(0.7376, device='cuda:0')
#
#
# Epoch =  6
# Epoch loss =  0.6830833584678416
# Epoch accuracy =  tensor(0.7667, device='cuda:0')
#
#
# Epoch =  7
# Epoch loss =  0.5906713446792291
# Epoch accuracy =  tensor(0.7909, device='cuda:0')
#
#
# Epoch =  8
# Epoch loss =  0.5184199937752315
# Epoch accuracy =  tensor(0.8036, device='cuda:0')
#
#
# Epoch =  9
# Epoch loss =  0.46341157780618086
# Epoch accuracy =  tensor(0.8125, device='cuda:0')
#
#
# Epoch =  10
# Epoch loss =  0.4057098037126113
# Epoch accuracy =  tensor(0.8144, device='cuda:0')
#
#
# Epoch =  11
# Epoch loss =  0.3644973617427203
# Epoch accuracy =  tensor(0.8293, device='cuda:0')
#
#
# Epoch =  12
# Epoch loss =  0.3194667570749108
# Epoch accuracy =  tensor(0.8271, device='cuda:0')
#
#
# Epoch =  13
# Epoch loss =  0.28309955721607016
# Epoch accuracy =  tensor(0.8270, device='cuda:0')
#
#
# Epoch =  14
# Epoch loss =  0.2538790921775662
# Epoch accuracy =  tensor(0.8433, device='cuda:0')
#
#
# Epoch =  15
# Epoch loss =  0.21663555670149473
# Epoch accuracy =  tensor(0.8349, device='cuda:0')
#
#
# Epoch =  16
# Epoch loss =  0.19412503938893882
# Epoch accuracy =  tensor(0.8275, device='cuda:0')
#
#
# Epoch =  17
# Epoch loss =  0.1695746121053793
# Epoch accuracy =  tensor(0.8298, device='cuda:0')
#
#
# Epoch =  18
# Epoch loss =  0.14393705160033946
# Epoch accuracy =  tensor(0.8345, device='cuda:0')
#
#
# Epoch =  19
# Epoch loss =  0.13343853488260385
# Epoch accuracy =  tensor(0.8425, device='cuda:0')
#
#
# Epoch =  20
# Epoch loss =  0.10517787389761331
# Epoch accuracy =  tensor(0.8393, device='cuda:0')
#
#
# Epoch =  21
# Epoch loss =  0.09556374003236391
# Epoch accuracy =  tensor(0.8439, device='cuda:0')
#
#
# Epoch =  22
# Epoch loss =  0.08658848980403676
# Epoch accuracy =  tensor(0.8382, device='cuda:0')
#
#
# Epoch =  23
# Epoch loss =  0.08200402109294522
# Epoch accuracy =  tensor(0.8448, device='cuda:0')
#
#
# Epoch =  24
# Epoch loss =  0.0756097757352554
# Epoch accuracy =  tensor(0.8410, device='cuda:0')
#
#
# Epoch =  25
# Epoch loss =  0.06837748511865431
# Epoch accuracy =  tensor(0.8380, device='cuda:0')
#
#
# Epoch =  26
# Epoch loss =  0.06469808838197164
# Epoch accuracy =  tensor(0.8412, device='cuda:0')
#
#
# Epoch =  27
# Epoch loss =  0.059858386138720174
# Epoch accuracy =  tensor(0.8382, device='cuda:0')
#
#
# Epoch =  28
# Epoch loss =  0.06638810762717408
# Epoch accuracy =  tensor(0.8488, device='cuda:0')
#
#
# Epoch =  29
# Epoch loss =  0.0550162781562124
# Epoch accuracy =  tensor(0.8444, device='cuda:0')
#
#
# Epoch =  30
# Epoch loss =  0.05093575869591869
# Epoch accuracy =  tensor(0.8401, device='cuda:0')
#
#
# Epoch =  31
# Epoch loss =  0.05870674858439942
# Epoch accuracy =  tensor(0.8448, device='cuda:0')
#
#
# Epoch =  32
# Epoch loss =  0.05071033911817536
# Epoch accuracy =  tensor(0.8428, device='cuda:0')
#
#
# Epoch =  33
# Epoch loss =  0.047175469143050056
# Epoch accuracy =  tensor(0.8487, device='cuda:0')
#
#
# Epoch =  34
# Epoch loss =  0.04413635378741488
# Epoch accuracy =  tensor(0.8454, device='cuda:0')
#
#
# Epoch =  35
# Epoch loss =  0.050670547106740425
# Epoch accuracy =  tensor(0.8453, device='cuda:0')
#
#
# Epoch =  36
# Epoch loss =  0.050544558264011025
# Epoch accuracy =  tensor(0.8394, device='cuda:0')
#
#
# Epoch =  37
# Epoch loss =  0.04778848495334387
# Epoch accuracy =  tensor(0.8441, device='cuda:0')
#
#
# Epoch =  38
# Epoch loss =  0.049803724056299854
# Epoch accuracy =  tensor(0.8467, device='cuda:0')
#
#
# Epoch =  39
# Epoch loss =  0.042594055692684284
# Epoch accuracy =  tensor(0.8428, device='cuda:0')
#
#
# Epoch =  40
# Epoch loss =  0.04122004663685755
# Epoch accuracy =  tensor(0.8435, device='cuda:0')
#
#
# Epoch =  41
# Epoch loss =  0.043191210347778945
# Epoch accuracy =  tensor(0.8491, device='cuda:0')
#
#
# Epoch =  42
# Epoch loss =  0.04165107247476675
# Epoch accuracy =  tensor(0.8451, device='cuda:0')
#
#
# Epoch =  43
# Epoch loss =  0.04496296968463124
# Epoch accuracy =  tensor(0.8454, device='cuda:0')
#
#
# Epoch =  44
# Epoch loss =  0.04071707921862906
# Epoch accuracy =  tensor(0.8473, device='cuda:0')
#
#
# Epoch =  45
# Epoch loss =  0.041412137591337064
# Epoch accuracy =  tensor(0.8478, device='cuda:0')
#
#
# Epoch =  46
# Epoch loss =  0.04000895099752411
# Epoch accuracy =  tensor(0.8475, device='cuda:0')
#
#
# Epoch =  47
# Epoch loss =  0.03850267965308562
# Epoch accuracy =  tensor(0.8457, device='cuda:0')
#
#
# Epoch =  48
# Epoch loss =  0.040917941834777594
# Epoch accuracy =  tensor(0.8420, device='cuda:0')
#
#
# Epoch =  49
# Epoch loss =  0.043166790119543365
# Epoch accuracy =  tensor(0.8490, device='cuda:0')
#
#
# Epoch =  50
# Epoch loss =  0.03529329896353337
# Epoch accuracy =  tensor(0.8459, device='cuda:0')
#
#
# Epoch =  51
# Epoch loss =  0.04575931208626348
# Epoch accuracy =  tensor(0.8474, device='cuda:0')
#
#
# Epoch =  52
# Epoch loss =  0.036938762444318554
# Epoch accuracy =  tensor(0.8487, device='cuda:0')
#
#
# Epoch =  53
# Epoch loss =  0.033976505795607764
# Epoch accuracy =  tensor(0.8496, device='cuda:0')
#
#
# Epoch =  54
# Epoch loss =  0.030915101410402934
# Epoch accuracy =  tensor(0.8442, device='cuda:0')
#
#
# Epoch =  55
# Epoch loss =  0.038958872620928654
# Epoch accuracy =  tensor(0.8424, device='cuda:0')
#
#
# Epoch =  56
# Epoch loss =  0.041124609032911916
# Epoch accuracy =  tensor(0.8383, device='cuda:0')
#
#
# Epoch =  57
# Epoch loss =  0.04478317923007571
# Epoch accuracy =  tensor(0.8503, device='cuda:0')
#
#
# Epoch =  58
# Epoch loss =  0.03133808652281153
# Epoch accuracy =  tensor(0.8431, device='cuda:0')
#
#
# Epoch =  59
# Epoch loss =  0.03835862065304299
# Epoch accuracy =  tensor(0.8492, device='cuda:0')
#
#
# Epoch =  60
# Epoch loss =  0.034189969524551105
# Epoch accuracy =  tensor(0.8467, device='cuda:0')
#
#
# Epoch =  61
# Epoch loss =  0.03788915166289222
# Epoch accuracy =  tensor(0.8459, device='cuda:0')
#
#
# Epoch =  62
# Epoch loss =  0.03608052197805777
# Epoch accuracy =  tensor(0.8487, device='cuda:0')
#
#
# Epoch =  63
# Epoch loss =  0.03044315797219775
# Epoch accuracy =  tensor(0.8477, device='cuda:0')
#
#
# Epoch =  64
# Epoch loss =  0.02566044366614399
# Epoch accuracy =  tensor(0.8478, device='cuda:0')
#
#
# Epoch =  65
# Epoch loss =  0.043963574785359054
# Epoch accuracy =  tensor(0.8463, device='cuda:0')
#
#
# Epoch =  66
# Epoch loss =  0.038858772169950664
# Epoch accuracy =  tensor(0.8481, device='cuda:0')
#
#
# Epoch =  67
# Epoch loss =  0.035876138439896156
# Epoch accuracy =  tensor(0.8560, device='cuda:0')
#
#
# Epoch =  68
# Epoch loss =  0.02581801725912611
# Epoch accuracy =  tensor(0.8493, device='cuda:0')
#
#
# Epoch =  69
# Epoch loss =  0.03216754345755492
# Epoch accuracy =  tensor(0.8446, device='cuda:0')
#
#
# Epoch =  70
# Epoch loss =  0.03299246647642279
# Epoch accuracy =  tensor(0.8452, device='cuda:0')
#
#
# Epoch =  71
# Epoch loss =  0.03146016710836973
# Epoch accuracy =  tensor(0.8466, device='cuda:0')
#
#
# Epoch =  72
# Epoch loss =  0.032844018542720954
# Epoch accuracy =  tensor(0.8508, device='cuda:0')
#
#
# Epoch =  73
# Epoch loss =  0.03486498428166521
# Epoch accuracy =  tensor(0.8469, device='cuda:0')
#
#
# Epoch =  74
# Epoch loss =  0.031134684921755473
# Epoch accuracy =  tensor(0.8509, device='cuda:0')
#
#
# Epoch =  75
# Epoch loss =  0.03085183602168548
# Epoch accuracy =  tensor(0.8479, device='cuda:0')
#
#
# Epoch =  76
# Epoch loss =  0.02988121542148292
# Epoch accuracy =  tensor(0.8490, device='cuda:0')
#
#
# Epoch =  77
# Epoch loss =  0.03586712008228107
# Epoch accuracy =  tensor(0.8413, device='cuda:0')
#
#
# Epoch =  78
# Epoch loss =  0.039650799516512424
# Epoch accuracy =  tensor(0.8457, device='cuda:0')
#
#
# Epoch =  79
# Epoch loss =  0.029183713367626984
# Epoch accuracy =  tensor(0.8484, device='cuda:0')

# %%
# !python ./experiments/cifar10/train_augerino.py --epochs=200 \
#                  --lr=0.01 \
#                  --wd=1e-4 \
#                  --transform="none" \
#                  --dir="/nfs/students/ayle/guided-research/gitignored/results/invariances/" \
#                  --data_dir="/nfs/students/ayle/guided-research/gitignored/data" \
#                  --ncopies=4 \
#                  --batch_size=128
